# %% [markdown]
# <a href="https://colab.research.google.com/github/gerardoemiliodorado-ship-it/Probabilidad-y-estad-stica-/blob/main/Unidad1/Pr%C3%A1ctica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# # Unidad 1
# ## **práctica 2** Máximo, mínimo, Rango y despersión de datos
# ###Docente: Jose Gabriel Rodriguez Rivas
# ###Alumno: Gerardo Emilio Dorado Navarrete

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

fabrica1 = []
for i in range(100):
  random_number = round(random.uniform(50, 100), 2)
  fabrica1.append(random_number)
print(fabrica1)

fabrica2 = []
for i in range(100):
  random_number = round(random.uniform(50, 100), 2)
  fabrica2.append(random_number)
print(fabrica2)

max1= max(fabrica1)
min1= min(fabrica1)
media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
rango1= max1-min1
desviacion1= stdev(fabrica1)

max2= max(fabrica2)
min2= min(fabrica2)
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
rango2= max2-min2
desviacion2= stdev(fabrica2)

print("Estadistica Descriptiva de la fabrica 1 \n", "Media =", media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo=", max1,
      "\n Minimo =", min1, "\n Rango =", rango1, "\n Desviacion:", desviacion1)
print("")
print("Estadistica Descriptiva de la fabrica 2 \n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo=", max2,
      "\n Minimo =", min2, "\n Rango =", rango2, "\n Desviacion:", desviacion2)
# Out:
# [99.97, 67.35, 95.9, 81.4, 84.24, 84.3, 93.06, 68.56, 72.54, 59.93, 53.33, 59.15, 68.45, 76.98, 55.08, 66.48, 81.03, 63.41, 50.86, 92.16, 98.53, 68.7, 78.5, 80.94, 95.57, 91.85, 74.44, 56.97, 64.22, 70.14, 89.94, 82.82, 90.28, 72.63, 75.25, 53.35, 64.13, 53.87, 89.08, 62.65, 77.78, 54.71, 92.19, 82.87, 81.76, 65.78, 73.18, 97.19, 91.47, 96.28, 54.89, 56.81, 77.45, 66.52, 89.72, 98.03, 61.98, 57.85, 59.22, 55.7, 64.55, 77.74, 63.43, 77.88, 52.96, 65.82, 81.59, 66.92, 71.43, 76.68, 52.25, 68.34, 92.43, 54.02, 83.51, 58.96, 94.32, 99.45, 51.21, 70.99, 50.48, 51.58, 62.38, 87.95, 82.68, 72.55, 63.99, 96.23, 82.78, 89.88, 81.54, 65.73, 59.34, 86.44, 62.61, 67.84, 59.57, 80.92, 87.72, 60.42]
# [76.68, 90.91, 82.44, 69.35, 92.24, 71.34, 51.45, 85.23, 93.27, 53.66, 55.7, 89.29, 82.56, 93.33, 76.24, 63.24, 81.3, 51.24, 88.43, 63.4, 89.15, 80.52, 86.72, 88.48, 52.34, 87.39, 82.89, 79.26, 71.63, 50.85, 70.81, 87.6, 72.81, 76.65, 82.96, 72.84, 55.35, 98.91, 51.45, 97.17, 78.16, 81.45, 86.15, 93.89, 61.21, 62.19, 56.57, 89.78, 81.53, 98.85, 98.09, 86.49, 63.69, 93.52, 86.7, 99.43, 79.63, 83.95, 96.89, 74.6, 58.68, 65.88, 73.71, 99.02, 63.65, 60.15, 81.38, 91.05, 67.21, 93.68, 98.91, 58.35, 96.97, 60.57, 93.44, 68.71, 50.26, 57.43, 51.23, 83.03, 70.58, 86.67, 96.61, 84.02, 66.56, 86.13, 77.54, 87.08, 56.12, 60.59, 60.97, 95.82, 90.36, 74.14, 95.85, 55.18, 80.89, 97.32, 57.41, 54.31]
# Estadistica Descriptiva de la fabrica 1
#  Media = 73.5653
#  Mediana = 72.545
#  Moda = 99.97
#  Maximo= 99.97
#  Minimo = 50.48
#  Rango = 49.49
#  Desviacion: 14.354680822827532
#
# Estadistica Descriptiva de la fabrica 2
#  Media = 77.0731
#  Mediana = 80.705
#  Moda = 51.45
#  Maximo= 99.43
#  Minimo = 50.26
#  Rango = 49.17000000000001
#  Desviacion: 15.039258974262976

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion1:.2f}')
plt.axvline(media1 + desviacion1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media1 - desviacion2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion2:.2f}')
plt.axvline(media1 + desviacion2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
from matplotlib.axes import Axes
import seaborn as sns

sns.histplot( x=fabrica1, kde= True, kde_kws={'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( x=fabrica2, kde= True, kde_kws={'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
