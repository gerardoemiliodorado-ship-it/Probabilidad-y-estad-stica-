# %% [markdown]
# <a href="https://colab.research.google.com/github/gerardoemiliodorado-ship-it/Probabilidad-y-estad-stica-/blob/main/Unidad3/Pr%C3%A1ctica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# # Unidad 1
# ## **práctica 3** Tabla de frecuencias y regla de Sturges.
# ###Alumno: Gerardo Emilio Dorado Navarrete

# %%
import random
import pandas as pd

edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [34, 28, 58, 43, 34, 49, 62, 58, 58, 30, 44, 58, 68, 57, 51, 41, 69, 37, 23, 57, 52, 51, 53, 60, 57, 54, 51, 50, 65, 55, 43, 62, 25, 61, 19, 59, 45, 37, 39, 31, 63, 20, 47, 61, 65, 57, 29, 36, 46, 47, 20, 61, 43, 56, 35, 26, 31, 67, 25, 41, 54, 70, 49, 44, 63, 70, 39, 29, 59, 22, 63, 19, 21, 63, 48, 24, 67, 54, 30, 41, 65, 62, 53, 21, 65, 23, 63, 25, 66, 52, 37, 19, 54, 30, 30, 66, 67, 31, 51, 66]

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    34
# 1    28
# 2    58
# 3    43
# 4    34

# %%
tabla_frec = df['Edad'].value_counts().reset_index()
tabla_frec.columns = ['Edad', 'Frecuencia']
tabla_frec = tabla_frec.sort_values(by='Edad')

print("Tabla de distribucion de frecuencias:")
tabla_frec
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 11    19           3
# 25    20           2
# 22    21           2
# 41    22           1
# 28    23           2
# 44    24           1
# 16    25           3
# 42    26           1
# 31    28           1
# 29    29           2
# 3     30           4
# 8     31           3
# 18    34           2
# 37    35           1
# 40    36           1
# 9     37           3
# 23    39           2
# 7     41           3
# 12    43           3
# 20    44           2
# 33    45           1
# 39    46           1
# 19    47           2
# 43    48           1
# 17    49           2
# 36    50           1
# 2     51           4
# 27    52           2
# 24    53           2
# 6     54           4
# 34    55           1
# 38    56           1
# 1     57           4
# 4     58           4
# 26    59           2
# 35    60           1
# 15    61           3
# 10    62           3
# 0     63           5
# 5     65           4
# 14    66           3
# 13    67           3
# 32    68           1
# 30    69           1
# 21    70           2

# %%
tabla_frec['Frec Relativa'] = tabla_frec['Frecuencia'] / 100
tabla_frec
# Out:
#     Edad  Frecuencia  Frec Relativa
# 11    19           3           0.03
# 25    20           2           0.02
# 22    21           2           0.02
# 41    22           1           0.01
# 28    23           2           0.02
# 44    24           1           0.01
# 16    25           3           0.03
# 42    26           1           0.01
# 31    28           1           0.01
# 29    29           2           0.02
# 3     30           4           0.04
# 8     31           3           0.03
# 18    34           2           0.02
# 37    35           1           0.01
# 40    36           1           0.01
# 9     37           3           0.03
# 23    39           2           0.02
# 7     41           3           0.03
# 12    43           3           0.03
# 20    44           2           0.02
# 33    45           1           0.01
# 39    46           1           0.01
# 19    47           2           0.02
# 43    48           1           0.01
# 17    49           2           0.02
# 36    50           1           0.01
# 2     51           4           0.04
# 27    52           2           0.02
# 24    53           2           0.02
# 6     54           4           0.04
# 34    55           1           0.01
# 38    56           1           0.01
# 1     57           4           0.04
# 4     58           4           0.04
# 26    59           2           0.02
# 35    60           1           0.01
# 15    61           3           0.03
# 10    62           3           0.03
# 0     63           5           0.05
# 5     65           4           0.04
# 14    66           3           0.03
# 13    67           3           0.03
# 32    68           1           0.01
# 30    69           1           0.01
# 21    70           2           0.02

# %%
tabla_frec['Frec Porcentual'] = tabla_frec['Frecuencia'] / 100 * 100
tabla_frec
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 11    19           3           0.03              3.0
# 25    20           2           0.02              2.0
# 22    21           2           0.02              2.0
# 41    22           1           0.01              1.0
# 28    23           2           0.02              2.0
# 44    24           1           0.01              1.0
# 16    25           3           0.03              3.0
# 42    26           1           0.01              1.0
# 31    28           1           0.01              1.0
# 29    29           2           0.02              2.0
# 3     30           4           0.04              4.0
# 8     31           3           0.03              3.0
# 18    34           2           0.02              2.0
# 37    35           1           0.01              1.0
# 40    36           1           0.01              1.0
# 9     37           3           0.03              3.0
# 23    39           2           0.02              2.0
# 7     41           3           0.03              3.0
# 12    43           3           0.03              3.0
# 20    44           2           0.02              2.0
# 33    45           1           0.01              1.0
# 39    46           1           0.01              1.0
# 19    47           2           0.02              2.0
# 43    48           1           0.01              1.0
# 17    49           2           0.02              2.0
# 36    50           1           0.01              1.0
# 2     51           4           0.04              4.0
# 27    52           2           0.02              2.0
# 24    53           2           0.02              2.0
# 6     54           4           0.04              4.0
# 34    55           1           0.01              1.0
# 38    56           1           0.01              1.0
# 1     57           4           0.04              4.0
# 4     58           4           0.04              4.0
# 26    59           2           0.02              2.0
# 35    60           1           0.01              1.0
# 15    61           3           0.03              3.0
# 10    62           3           0.03              3.0
# 0     63           5           0.05              5.0
# 5     65           4           0.04              4.0
# 14    66           3           0.03              3.0
# 13    67           3           0.03              3.0
# 32    68           1           0.01              1.0
# 30    69           1           0.01              1.0
# 21    70           2           0.02              2.0

# %%
tabla_frec['Frec Acumulada'] = tabla_frec['Frecuencia'].cumsum()
tabla_frec
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 11    19           3           0.03              3.0               3
# 25    20           2           0.02              2.0               5
# 22    21           2           0.02              2.0               7
# 41    22           1           0.01              1.0               8
# 28    23           2           0.02              2.0              10
# 44    24           1           0.01              1.0              11
# 16    25           3           0.03              3.0              14
# 42    26           1           0.01              1.0              15
# 31    28           1           0.01              1.0              16
# 29    29           2           0.02              2.0              18
# 3     30           4           0.04              4.0              22
# 8     31           3           0.03              3.0              25
# 18    34           2           0.02              2.0              27
# 37    35           1           0.01              1.0              28
# 40    36           1           0.01              1.0              29
# 9     37           3           0.03              3.0              32
# 23    39           2           0.02              2.0              34
# 7     41           3           0.03              3.0              37
# 12    43           3           0.03              3.0              40
# 20    44           2           0.02              2.0              42
# 33    45           1           0.01              1.0              43
# 39    46           1           0.01              1.0              44
# 19    47           2           0.02              2.0              46
# 43    48           1           0.01              1.0              47
# 17    49           2           0.02              2.0              49
# 36    50           1           0.01              1.0              50
# 2     51           4           0.04              4.0              54
# 27    52           2           0.02              2.0              56
# 24    53           2           0.02              2.0              58
# 6     54           4           0.04              4.0              62
# 34    55           1           0.01              1.0              63
# 38    56           1           0.01              1.0              64
# 1     57           4           0.04              4.0              68
# 4     58           4           0.04              4.0              72
# 26    59           2           0.02              2.0              74
# 35    60           1           0.01              1.0              75
# 15    61           3           0.03              3.0              78
# 10    62           3           0.03              3.0              81
# 0     63           5           0.05              5.0              86
# 5     65           4           0.04              4.0              90
# 14    66           3           0.03              3.0              93
# 13    67           3           0.03              3.0              96
# 32    68           1           0.01              1.0              97
# 30    69           1           0.01              1.0              98
# 21    70           2           0.02              2.0             100

# %%
import math
print(edades)
df = pd.DataFrame(edades, columns=['Edad'])
df

n =len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n, "\nNumero de intervalos =", K)

tabla_frecuencia = pd.cut(df['Edad'], bins=K).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
# [34, 28, 58, 43, 34, 49, 62, 58, 58, 30, 44, 58, 68, 57, 51, 41, 69, 37, 23, 57, 52, 51, 53, 60, 57, 54, 51, 50, 65, 55, 43, 62, 25, 61, 19, 59, 45, 37, 39, 31, 63, 20, 47, 61, 65, 57, 29, 36, 46, 47, 20, 61, 43, 56, 35, 26, 31, 67, 25, 41, 54, 70, 49, 44, 63, 70, 39, 29, 59, 22, 63, 19, 21, 63, 48, 24, 67, 54, 30, 41, 65, 62, 53, 21, 65, 23, 63, 25, 66, 52, 37, 19, 54, 30, 30, 66, 67, 31, 51, 66]
# Valor de n =  100
# Numero de intervalos = 7
#               Clase  Frec
# 0    (62.714, 70.0]    19
# 1  (55.429, 62.714]    18
# 2  (48.143, 55.429]    16
# 3  (18.949, 26.286]    15
# 4  (40.857, 48.143]    13
# 5  (26.286, 33.571]    10
# 6  (33.571, 40.857]     9

# %%
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 3  (18.949, 26.286]    15
# 5  (26.286, 33.571]    10
# 6  (33.571, 40.857]     9
# 4  (40.857, 48.143]    13
# 2  (48.143, 55.429]    16
# 1  (55.429, 62.714]    18
# 0    (62.714, 70.0]    19

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Drec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)

import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title('Histograma de edades')
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Drec Rel Ac  \
# 3  (18.949, 26.286]    15      0.15       15.0       15         0.15
# 5  (26.286, 33.571]    10      0.10       10.0       25         0.25
# 6  (33.571, 40.857]     9      0.09        9.0       34         0.34
# 4  (40.857, 48.143]    13      0.13       13.0       47         0.47
# 2  (48.143, 55.429]    16      0.16       16.0       63         0.63
# 1  (55.429, 62.714]    18      0.18       18.0       81         0.81
# 0    (62.714, 70.0]    19      0.19       19.0      100         1.00
#
#    Frec Porc Ac
# 3          15.0
# 5          25.0
# 6          34.0
# 4          47.0
# 2          63.0
# 1          81.0
# 0         100.0
# Text(0.5, 1.0, 'Histograma de edades')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
